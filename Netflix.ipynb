# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("netflix.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
#Renaming the listed in column to genre
df.rename(columns={'listed_in':'genre'},inplace=True)
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'genre', 'description'],
#       dtype='object')

# %%
#Droping the show_id columns as it may be of no use in the analysis
df.drop(columns='show_id',inplace=True)

# %%
#Checking for duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Checking missing values
df.isnull().sum()
# Out:
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# genre              0
# description        0
# dtype: int64

# %%
#here we can see clearily here some count are so big and
#some are so small which is available in less quantity
#we can drop them

# %%
#As we have studied
#if we write df.dropna()----all the rows having missing value
#got deleted
#if we write df.dropna(axis=1)the having missing value got deleted
#if we want to delete missing value from specific column
#df.dropna(subset={"Column_name"},axis=1,inplace=True)

# %%
df.shape
# Out:
# (8807, 11)

# %%
#Droping the rows which have null values in date_added
#columns as there are 0nly 10 values
df.dropna(subset=['date_added'],inplace=True)
df['date_added'].isna().sum()
# Out:
# np.int64(0)

# %%
#Droping the rows which have null values in rating columns
#as there are only 4 values
df.dropna(subset=['rating'],inplace=True)
df['rating'].isna().sum()
# Out:
# np.int64(0)

# %%
#Droping the rows which have null values in duration
#columns as there are 3 values
df.dropna(subset=['duration'],inplace=True)
df['duration'].isna().sum()
# Out:
# np.int64(0)

# %%
#when there is some mismatch in our date format then that
#value is replaced by null
df['date_added']=pd.to_datetime(df['date_added'],errors='coerce')
df['date_added'].isna().sum()
# Out:
# np.int64(88)

# %%
df.dropna(subset=['date_added'],inplace=True)
df['date_added'].isna().sum()
# Out:
# np.int64(0)

# %%
df['day']=df['date_added'].dt.day
df['month']=df['date_added'].dt.month
df['year']=df['date_added'].dt.year
df['month_name']=df['date_added'].dt.month_name()
df['weekday']=df['date_added'].dt.day_name()
df.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# 4 2021-09-24          2021  TV-MA  2 Seasons
#
#                                                genre  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description  day  month  year  \
# 0  As her father nears the end of his life, filmm...   25      9  2021
# 1  After crossing paths at a party, a Cape Town t...   24      9  2021
# 2  To protect his family from a powerful drug lor...   24      9  2021
# 3  Feuds, flirtations and toilet talk go down amo...   24      9  2021
# 4  In a city of coaching centers known to train I...   24      9  2021
#
#   month_name   weekday
# 0  September  Saturday
# 1  September    Friday
# 2  September    Friday
# 3  September    Friday
# 4  September    Friday

# %%
df["duration"].unique()
# Out:
# array(['90 min', '2 Seasons', '1 Season', '91 min', '125 min',
#        '9 Seasons', '104 min', '127 min', '4 Seasons', '67 min', '94 min',
#        '5 Seasons', '161 min', '61 min', '166 min', '147 min', '103 min',
#        '97 min', '106 min', '111 min', '3 Seasons', '110 min', '105 min',
#        '96 min', '124 min', '116 min', '98 min', '23 min', '115 min',
#        '122 min', '99 min', '88 min', '100 min', '6 Seasons', '102 min',
#        '93 min', '95 min', '85 min', '83 min', '113 min', '13 min',
#        '182 min', '48 min', '145 min', '87 min', '92 min', '80 min',
#        '117 min', '128 min', '119 min', '143 min', '114 min', '118 min',
#        '108 min', '63 min', '121 min', '142 min', '154 min', '120 min',
#        '82 min', '109 min', '101 min', '86 min', '229 min', '76 min',
#        '89 min', '156 min', '112 min', '107 min', '129 min', '135 min',
#        '136 min', '165 min', '150 min', '133 min', '70 min', '84 min',
#        '140 min', '78 min', '7 Seasons', '64 min', '59 min', '139 min',
#        '69 min', '148 min', '189 min', '141 min', '130 min', '138 min',
#        '81 min', '132 min', '10 Seasons', '123 min', '65 min', '68 min',
#        '66 min', '62 min', '74 min', '131 min', '39 min', '46 min',
#        '38 min', '8 Seasons', '17 Seasons', '126 min', '155 min',
#        '159 min', '137 min', '12 min', '273 min', '36 min', '34 min',
#        '77 min', '60 min', '49 min', '58 min', '72 min', '204 min',
#        '212 min', '25 min', '73 min', '29 min', '47 min', '32 min',
#        '35 min', '71 min', '149 min', '33 min', '15 min', '54 min',
#        '224 min', '162 min', '37 min', '75 min', '79 min', '55 min',
#        '158 min', '164 min', '173 min', '181 min', '185 min', '21 min',
#        '24 min', '51 min', '151 min', '42 min', '22 min', '134 min',
#        '177 min', '13 Seasons', '52 min', '14 min', '53 min', '8 min',
#        '57 min', '28 min', '50 min', '9 min', '26 min', '45 min',
#        '171 min', '27 min', '44 min', '146 min', '20 min', '157 min',
#        '17 min', '203 min', '41 min', '30 min', '194 min', '15 Seasons',
#        '233 min', '237 min', '230 min', '195 min', '253 min', '152 min',
#        '190 min', '160 min', '208 min', '180 min', '144 min', '5 min',
#        '174 min', '170 min', '192 min', '209 min', '187 min', '172 min',
#        '16 min', '186 min', '11 min', '193 min', '176 min', '56 min',
#        '169 min', '40 min', '10 min', '3 min', '168 min', '312 min',
#        '153 min', '214 min', '31 min', '163 min', '19 min', '12 Seasons',
#        '179 min', '43 min', '200 min', '196 min', '167 min', '178 min',
#        '228 min', '18 min', '205 min', '201 min', '191 min'], dtype=object)

# %%
s1='179 min'
int(s1.split()[0])
# Out:
# 179

# %%
s1='12 Season'
int(s1.split()[0])
# Out:
# 12

# %%
df["duration"]=df["duration"].apply(lambda x:int(x.split()[0]))

# %%
df["duration"].unique()
# Out:
# array([ 90,   2,   1,  91, 125,   9, 104, 127,   4,  67,  94,   5, 161,
#         61, 166, 147, 103,  97, 106, 111,   3, 110, 105,  96, 124, 116,
#         98,  23, 115, 122,  99,  88, 100,   6, 102,  93,  95,  85,  83,
#        113,  13, 182,  48, 145,  87,  92,  80, 117, 128, 119, 143, 114,
#        118, 108,  63, 121, 142, 154, 120,  82, 109, 101,  86, 229,  76,
#         89, 156, 112, 107, 129, 135, 136, 165, 150, 133,  70,  84, 140,
#         78,   7,  64,  59, 139,  69, 148, 189, 141, 130, 138,  81, 132,
#         10, 123,  65,  68,  66,  62,  74, 131,  39,  46,  38,   8,  17,
#        126, 155, 159, 137,  12, 273,  36,  34,  77,  60,  49,  58,  72,
#        204, 212,  25,  73,  29,  47,  32,  35,  71, 149,  33,  15,  54,
#        224, 162,  37,  75,  79,  55, 158, 164, 173, 181, 185,  21,  24,
#         51, 151,  42,  22, 134, 177,  52,  14,  53,  57,  28,  50,  26,
#         45, 171,  27,  44, 146,  20, 157, 203,  41,  30, 194, 233, 237,
#        230, 195, 253, 152, 190, 160, 208, 180, 144, 174, 170, 192, 209,
#        187, 172,  16, 186,  11, 193, 176,  56, 169,  40, 168, 312, 153,
#        214,  31, 163,  19, 179,  43, 200, 196, 167, 178, 228,  18, 205,
#        201, 191])

# %%
#Checking for unique values of rating and categorising them for better understanding
df["rating"].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
df["rating"]=df["rating"].replace(["TV-Y","TV-Y7","G","TV-G","PG","TV-PG","TV-Y7-FV"],"Kids")
df["rating"]=df["rating"].replace(["PG-13","TV-14",],"Teens")
df["rating"]=df["rating"].replace(["R","TV-MA","NC-17",],"Adults")
df["rating"]=df["rating"].replace(["NR","UR"],np.nan)
df.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year  rating  duration  \
# 0 2021-09-25          2020   Teens        90
# 1 2021-09-24          2021  Adults         2
# 2 2021-09-24          2021  Adults         1
# 3 2021-09-24          2021  Adults         1
# 4 2021-09-24          2021  Adults         2
#
#                                                genre  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description  day  month  year  \
# 0  As her father nears the end of his life, filmm...   25      9  2021
# 1  After crossing paths at a party, a Cape Town t...   24      9  2021
# 2  To protect his family from a powerful drug lor...   24      9  2021
# 3  Feuds, flirtations and toilet talk go down amo...   24      9  2021
# 4  In a city of coaching centers known to train I...   24      9  2021
#
#   month_name   weekday
# 0  September  Saturday
# 1  September    Friday
# 2  September    Friday
# 3  September    Friday
# 4  September    Friday

# %%
df["rating"].unique()
# Out:
# array(['Teens', 'Adults', 'Kids', nan], dtype=object)

# %%
df["rating"].isna().sum()
# Out:
# np.int64(81)

# %%
df.dropna(subset=["rating"],inplace=True)
df["rating"].isna().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum()
# Out:
# type               0
# title              0
# director        2535
# cast             800
# country          826
# date_added         0
# release_year       0
# rating             0
# duration           0
# genre              0
# description        0
# day                0
# month              0
# year               0
# month_name         0
# weekday            0
# dtype: int64

# %%
df[(df["director"].isna()) & (df["country"].isna()) & (df["cast"].isna())].shape[0]
# Out:
# 96

# %%
df.dropna(subset=["director","country","cast"],how="all",inplace=True)
df.shape
# Out:
# (8525, 16)

# %%
df["cast"][2].split(",")
# Out:
# ['Sami Bouajila',
#  ' Tracy Gotoas',
#  ' Samuel Jouy',
#  ' Nabiha Akkari',
#  ' Sofia Lesaffre',
#  ' Salim Kechiouche',
#  ' Noureddine Farihi',
#  ' Geert Van Rampelberg',
#  ' Bakary Diombera']

# %%
df_cast=pd.DataFrame(df["cast"].apply(lambda x: str(x).split(", ")).tolist(),index=df["title"])
df_cast
# Out:
#                                    0                1                  2   \
# title
# Dick Johnson Is Dead              nan             None               None
# Blood & Water              Ama Qamata      Khosi Ngema      Gail Mabalane
# Ganglands               Sami Bouajila     Tracy Gotoas        Samuel Jouy
# Kota Factory               Mayur More   Jitendra Kumar         Ranjan Raj
# Midnight Mass             Kate Siegel     Zach Gilford   Hamish Linklater
# ...                               ...              ...                ...
# Zinzana                   Ali Suliman      Saleh Bakri               Yasa
# Zodiac                   Mark Ruffalo  Jake Gyllenhaal  Robert Downey Jr.
# Zombieland            Jesse Eisenberg  Woody Harrelson         Emma Stone
# Zoom                        Tim Allen    Courteney Cox        Chevy Chase
# Zubaan                  Vicky Kaushal  Sarah-Jane Dias    Raaghav Chanana
#
#                                     3                 4                 5   \
# title
# Dick Johnson Is Dead              None              None              None
# Blood & Water           Thabang Molaba  Dillon Windvogel   Natasha Thahane
# Ganglands                Nabiha Akkari    Sofia Lesaffre  Salim Kechiouche
# Kota Factory                 Alam Khan     Ahsaas Channa    Revathi Pillai
# Midnight Mass             Henry Thomas    Kristin Lehman   Samantha Sloyan
# ...                                ...               ...               ...
# Zinzana                   Ali Al-Jabri   Mansoor Alfeeli               Ahd
# Zodiac                 Anthony Edwards         Brian Cox      Elias Koteas
# Zombieland             Abigail Breslin       Amber Heard       Bill Murray
# Zoom                         Kate Mara       Ryan Newman   Michael Cassidy
# Zubaan                Manish Chaudhary      Meghna Malik     Malkeet Rauni
#
#                                      6                      7   \
# title
# Dick Johnson Is Dead               None                   None
# Blood & Water               Arno Greeff      Xolile Tshabalala
# Ganglands             Noureddine Farihi   Geert Van Rampelberg
# Kota Factory                 Urvi Singh             Arun Kumar
# Midnight Mass               Igby Rigney            Rahul Kohli
# ...                                 ...                    ...
# Zinzana                            None                   None
# Zodiac                      Donal Logue     John Carroll Lynch
# Zombieland                   Derek Graf                   None
# Zoom                    Spencer Breslin               Rip Torn
# Zubaan                   Anita Shabdish  Chittaranjan Tripathy
#
#                                    8               9   ...    40    41    42  \
# title                                                  ...
# Dick Johnson Is Dead             None            None  ...  None  None  None
# Blood & Water         Getmore Sithole  Cindy Mahlangu  ...  None  None  None
# Ganglands             Bakary Diombera            None  ...  None  None  None
# Kota Factory                     None            None  ...  None  None  None
# Midnight Mass          Annarah Cymone   Annabeth Gish  ...  None  None  None
# ...                               ...             ...  ...   ...   ...   ...
# Zinzana                          None            None  ...  None  None  None
# Zodiac                Dermot Mulroney   Chloë Sevigny  ...  None  None  None
# Zombieland                       None            None  ...  None  None  None
# Zoom                     Kevin Zegers            None  ...  None  None  None
# Zubaan                           None            None  ...  None  None  None
#
#                         43    44    45    46    47    48    49
# title
# Dick Johnson Is Dead  None  None  None  None  None  None  None
# Blood & Water         None  None  None  None  None  None  None
# Ganglands             None  None  None  None  None  None  None
# Kota Factory          None  None  None  None  None  None  None
# Midnight Mass         None  None  None  None  None  None  None
# ...                    ...   ...   ...   ...   ...   ...   ...
# Zinzana               None  None  None  None  None  None  None
# Zodiac                None  None  None  None  None  None  None
# Zombieland            None  None  None  None  None  None  None
# Zoom                  None  None  None  None  None  None  None
# Zubaan                None  None  None  None  None  None  None
#
# [8525 rows x 50 columns]

# %%
df_cast=df_cast.stack()
df_cast
# Out:
# title
# Dick Johnson Is Dead  0                      nan
# Blood & Water         0               Ama Qamata
#                       1              Khosi Ngema
#                       2            Gail Mabalane
#                       3           Thabang Molaba
#                                    ...
# Zubaan                3         Manish Chaudhary
#                       4             Meghna Malik
#                       5            Malkeet Rauni
#                       6           Anita Shabdish
#                       7    Chittaranjan Tripathy
# Length: 63644, dtype: object

# %%
df_cast = pd.DataFrame(df_cast)
df_cast
# Out:
#                                             0
# title
# Dick Johnson Is Dead 0                    nan
# Blood & Water        0             Ama Qamata
#                      1            Khosi Ngema
#                      2          Gail Mabalane
#                      3         Thabang Molaba
# ...                                       ...
# Zubaan               3       Manish Chaudhary
#                      4           Meghna Malik
#                      5          Malkeet Rauni
#                      6         Anita Shabdish
#                      7  Chittaranjan Tripathy
#
# [63644 rows x 1 columns]

# %%
df_cast.reset_index(inplace=True)
df_cast
# Out:
#                       title  level_1                      0
# 0      Dick Johnson Is Dead        0                    nan
# 1             Blood & Water        0             Ama Qamata
# 2             Blood & Water        1            Khosi Ngema
# 3             Blood & Water        2          Gail Mabalane
# 4             Blood & Water        3         Thabang Molaba
# ...                     ...      ...                    ...
# 63639                Zubaan        3       Manish Chaudhary
# 63640                Zubaan        4           Meghna Malik
# 63641                Zubaan        5          Malkeet Rauni
# 63642                Zubaan        6         Anita Shabdish
# 63643                Zubaan        7  Chittaranjan Tripathy
#
# [63644 rows x 3 columns]

# %%
df_cast=df_cast[["title",0]]
df_cast
# Out:
#                       title                      0
# 0      Dick Johnson Is Dead                    nan
# 1             Blood & Water             Ama Qamata
# 2             Blood & Water            Khosi Ngema
# 3             Blood & Water          Gail Mabalane
# 4             Blood & Water         Thabang Molaba
# ...                     ...                    ...
# 63639                Zubaan       Manish Chaudhary
# 63640                Zubaan           Meghna Malik
# 63641                Zubaan          Malkeet Rauni
# 63642                Zubaan         Anita Shabdish
# 63643                Zubaan  Chittaranjan Tripathy
#
# [63644 rows x 2 columns]

# %%
df_cast.columns=["title","cast"]
df_cast
# Out:
#                       title                   cast
# 0      Dick Johnson Is Dead                    nan
# 1             Blood & Water             Ama Qamata
# 2             Blood & Water            Khosi Ngema
# 3             Blood & Water          Gail Mabalane
# 4             Blood & Water         Thabang Molaba
# ...                     ...                    ...
# 63639                Zubaan       Manish Chaudhary
# 63640                Zubaan           Meghna Malik
# 63641                Zubaan          Malkeet Rauni
# 63642                Zubaan         Anita Shabdish
# 63643                Zubaan  Chittaranjan Tripathy
#
# [63644 rows x 2 columns]

# %%
df_cast.replace("nan",np.nan,inplace=True)
df_cast.isna().sum()
# Out:
# /tmp/ipykernel_783/356088169.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cast.replace("nan",np.nan,inplace=True)
# title      0
# cast     704
# dtype: int64

# %%
df_genre=pd.DataFrame(df["genre"].apply(lambda x: str(x).split(", ")).tolist(),index=df["title"])
df_genre
# Out:
#                                              0                       1  \
# title
# Dick Johnson Is Dead             Documentaries                    None
# Blood & Water           International TV Shows               TV Dramas
# Ganglands                       Crime TV Shows  International TV Shows
# Kota Factory            International TV Shows       Romantic TV Shows
# Midnight Mass                        TV Dramas               TV Horror
# ...                                        ...                     ...
# Zinzana                                 Dramas    International Movies
# Zodiac                             Cult Movies                  Dramas
# Zombieland                            Comedies           Horror Movies
# Zoom                  Children & Family Movies                Comedies
# Zubaan                                  Dramas    International Movies
#
#                                           2
# title
# Dick Johnson Is Dead                   None
# Blood & Water                  TV Mysteries
# Ganglands             TV Action & Adventure
# Kota Factory                    TV Comedies
# Midnight Mass                  TV Mysteries
# ...                                     ...
# Zinzana                           Thrillers
# Zodiac                            Thrillers
# Zombieland                             None
# Zoom                                   None
# Zubaan                     Music & Musicals
#
# [8525 rows x 3 columns]

# %%
df_genre=df_genre.stack()
df_genre
# Out:
# title
# Dick Johnson Is Dead  0               Documentaries
# Blood & Water         0      International TV Shows
#                       1                   TV Dramas
#                       2                TV Mysteries
# Ganglands             0              Crime TV Shows
#                                      ...
# Zoom                  0    Children & Family Movies
#                       1                    Comedies
# Zubaan                0                      Dramas
#                       1        International Movies
#                       2            Music & Musicals
# Length: 18757, dtype: object

# %%
df_genre = pd.DataFrame(df_genre)
df_genre
# Out:
#                                                0
# title
# Dick Johnson Is Dead 0             Documentaries
# Blood & Water        0    International TV Shows
#                      1                 TV Dramas
#                      2              TV Mysteries
# Ganglands            0            Crime TV Shows
# ...                                          ...
# Zoom                 0  Children & Family Movies
#                      1                  Comedies
# Zubaan               0                    Dramas
#                      1      International Movies
#                      2          Music & Musicals
#
# [18757 rows x 1 columns]

# %%
df_genre.reset_index(inplace=True)
df_genre
# Out:
#                       title  level_1                         0
# 0      Dick Johnson Is Dead        0             Documentaries
# 1             Blood & Water        0    International TV Shows
# 2             Blood & Water        1                 TV Dramas
# 3             Blood & Water        2              TV Mysteries
# 4                 Ganglands        0            Crime TV Shows
# ...                     ...      ...                       ...
# 18752                  Zoom        0  Children & Family Movies
# 18753                  Zoom        1                  Comedies
# 18754                Zubaan        0                    Dramas
# 18755                Zubaan        1      International Movies
# 18756                Zubaan        2          Music & Musicals
#
# [18757 rows x 3 columns]

# %%
df_genre=df_genre[["title",0]]
df_genre
# Out:
#                       title                         0
# 0      Dick Johnson Is Dead             Documentaries
# 1             Blood & Water    International TV Shows
# 2             Blood & Water                 TV Dramas
# 3             Blood & Water              TV Mysteries
# 4                 Ganglands            Crime TV Shows
# ...                     ...                       ...
# 18752                  Zoom  Children & Family Movies
# 18753                  Zoom                  Comedies
# 18754                Zubaan                    Dramas
# 18755                Zubaan      International Movies
# 18756                Zubaan          Music & Musicals
#
# [18757 rows x 2 columns]

# %%
df_genre.columns=["title","genre"]
df_genre
# Out:
#                       title                     genre
# 0      Dick Johnson Is Dead             Documentaries
# 1             Blood & Water    International TV Shows
# 2             Blood & Water                 TV Dramas
# 3             Blood & Water              TV Mysteries
# 4                 Ganglands            Crime TV Shows
# ...                     ...                       ...
# 18752                  Zoom  Children & Family Movies
# 18753                  Zoom                  Comedies
# 18754                Zubaan                    Dramas
# 18755                Zubaan      International Movies
# 18756                Zubaan          Music & Musicals
#
# [18757 rows x 2 columns]

# %%
df_genre.replace("nan",np.nan,inplace=True)
df_genre.isna().sum()
# Out:
# /tmp/ipykernel_783/3535692094.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_genre.replace("nan",np.nan,inplace=True)
# title    0
# genre    0
# dtype: int64

# %%
df_director=pd.DataFrame(df["director"].apply(lambda x: str(x).split(", ")).tolist(),index=df["title"])
df_director
# Out:
#                                    0     1     2     3     4     5     6   \
# title
# Dick Johnson Is Dead  Kirsten Johnson  None  None  None  None  None  None
# Blood & Water                     nan  None  None  None  None  None  None
# Ganglands             Julien Leclercq  None  None  None  None  None  None
# Kota Factory                      nan  None  None  None  None  None  None
# Midnight Mass           Mike Flanagan  None  None  None  None  None  None
# ...                               ...   ...   ...   ...   ...   ...   ...
# Zinzana               Majid Al Ansari  None  None  None  None  None  None
# Zodiac                  David Fincher  None  None  None  None  None  None
# Zombieland            Ruben Fleischer  None  None  None  None  None  None
# Zoom                     Peter Hewitt  None  None  None  None  None  None
# Zubaan                    Mozez Singh  None  None  None  None  None  None
#
#                         7     8     9     10    11    12
# title
# Dick Johnson Is Dead  None  None  None  None  None  None
# Blood & Water         None  None  None  None  None  None
# Ganglands             None  None  None  None  None  None
# Kota Factory          None  None  None  None  None  None
# Midnight Mass         None  None  None  None  None  None
# ...                    ...   ...   ...   ...   ...   ...
# Zinzana               None  None  None  None  None  None
# Zodiac                None  None  None  None  None  None
# Zombieland            None  None  None  None  None  None
# Zoom                  None  None  None  None  None  None
# Zubaan                None  None  None  None  None  None
#
# [8525 rows x 13 columns]

# %%
df_director=df_director.stack()
df_director
# Out:
# title
# Dick Johnson Is Dead  0    Kirsten Johnson
# Blood & Water         0                nan
# Ganglands             0    Julien Leclercq
# Kota Factory          0                nan
# Midnight Mass         0      Mike Flanagan
#                                 ...
# Zinzana               0    Majid Al Ansari
# Zodiac                0      David Fincher
# Zombieland            0    Ruben Fleischer
# Zoom                  0       Peter Hewitt
# Zubaan                0        Mozez Singh
# Length: 9320, dtype: object

# %%
df_director = pd.DataFrame(df_director)
df_director
# Out:
#                                       0
# title
# Dick Johnson Is Dead 0  Kirsten Johnson
# Blood & Water        0              nan
# Ganglands            0  Julien Leclercq
# Kota Factory         0              nan
# Midnight Mass        0    Mike Flanagan
# ...                                 ...
# Zinzana              0  Majid Al Ansari
# Zodiac               0    David Fincher
# Zombieland           0  Ruben Fleischer
# Zoom                 0     Peter Hewitt
# Zubaan               0      Mozez Singh
#
# [9320 rows x 1 columns]

# %%
df_director.reset_index(inplace=True)
df_director
# Out:
#                      title  level_1                0
# 0     Dick Johnson Is Dead        0  Kirsten Johnson
# 1            Blood & Water        0              nan
# 2                Ganglands        0  Julien Leclercq
# 3             Kota Factory        0              nan
# 4            Midnight Mass        0    Mike Flanagan
# ...                    ...      ...              ...
# 9315               Zinzana        0  Majid Al Ansari
# 9316                Zodiac        0    David Fincher
# 9317            Zombieland        0  Ruben Fleischer
# 9318                  Zoom        0     Peter Hewitt
# 9319                Zubaan        0      Mozez Singh
#
# [9320 rows x 3 columns]

# %%
df_director=df_director[["title",0]]
df_director
# Out:
#                      title                0
# 0     Dick Johnson Is Dead  Kirsten Johnson
# 1            Blood & Water              nan
# 2                Ganglands  Julien Leclercq
# 3             Kota Factory              nan
# 4            Midnight Mass    Mike Flanagan
# ...                    ...              ...
# 9315               Zinzana  Majid Al Ansari
# 9316                Zodiac    David Fincher
# 9317            Zombieland  Ruben Fleischer
# 9318                  Zoom     Peter Hewitt
# 9319                Zubaan      Mozez Singh
#
# [9320 rows x 2 columns]

# %%
df_director.columns=["title","director"]
df_director
# Out:
#                      title         director
# 0     Dick Johnson Is Dead  Kirsten Johnson
# 1            Blood & Water              nan
# 2                Ganglands  Julien Leclercq
# 3             Kota Factory              nan
# 4            Midnight Mass    Mike Flanagan
# ...                    ...              ...
# 9315               Zinzana  Majid Al Ansari
# 9316                Zodiac    David Fincher
# 9317            Zombieland  Ruben Fleischer
# 9318                  Zoom     Peter Hewitt
# 9319                Zubaan      Mozez Singh
#
# [9320 rows x 2 columns]

# %%
df_director.replace("nan",np.nan,inplace=True)
df_director.isna().sum()
# Out:
# /tmp/ipykernel_783/3206080646.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_director.replace("nan",np.nan,inplace=True)
# title          0
# director    2439
# dtype: int64

# %%
df_country=pd.DataFrame(df["country"].apply(lambda x: str(x).split(", ")).tolist(),index=df["title"])
df_country
# Out:
#                                         0       1     2     3     4     5   \
# title
# Dick Johnson Is Dead         United States    None  None  None  None  None
# Blood & Water                 South Africa    None  None  None  None  None
# Ganglands                              nan    None  None  None  None  None
# Kota Factory                         India    None  None  None  None  None
# Midnight Mass                          nan    None  None  None  None  None
# ...                                    ...     ...   ...   ...   ...   ...
# Zinzana               United Arab Emirates  Jordan  None  None  None  None
# Zodiac                       United States    None  None  None  None  None
# Zombieland                   United States    None  None  None  None  None
# Zoom                         United States    None  None  None  None  None
# Zubaan                               India    None  None  None  None  None
#
#                         6     7     8     9     10    11
# title
# Dick Johnson Is Dead  None  None  None  None  None  None
# Blood & Water         None  None  None  None  None  None
# Ganglands             None  None  None  None  None  None
# Kota Factory          None  None  None  None  None  None
# Midnight Mass         None  None  None  None  None  None
# ...                    ...   ...   ...   ...   ...   ...
# Zinzana               None  None  None  None  None  None
# Zodiac                None  None  None  None  None  None
# Zombieland            None  None  None  None  None  None
# Zoom                  None  None  None  None  None  None
# Zubaan                None  None  None  None  None  None
#
# [8525 rows x 12 columns]

# %%
df_country=df_country.stack()
df_country
# Out:
# title
# Dick Johnson Is Dead  0    United States
# Blood & Water         0     South Africa
# Ganglands             0              nan
# Kota Factory          0            India
# Midnight Mass         0              nan
#                                ...
# Zinzana               1           Jordan
# Zodiac                0    United States
# Zombieland            0    United States
# Zoom                  0    United States
# Zubaan                0            India
# Length: 10519, dtype: object

# %%
df_country = pd.DataFrame(df_country)
df_country
# Out:
#                                     0
# title
# Dick Johnson Is Dead 0  United States
# Blood & Water        0   South Africa
# Ganglands            0            nan
# Kota Factory         0          India
# Midnight Mass        0            nan
# ...                               ...
# Zinzana              1         Jordan
# Zodiac               0  United States
# Zombieland           0  United States
# Zoom                 0  United States
# Zubaan               0          India
#
# [10519 rows x 1 columns]

# %%
df_country.reset_index(inplace=True)
df_country
# Out:
#                       title  level_1              0
# 0      Dick Johnson Is Dead        0  United States
# 1             Blood & Water        0   South Africa
# 2                 Ganglands        0            nan
# 3              Kota Factory        0          India
# 4             Midnight Mass        0            nan
# ...                     ...      ...            ...
# 10514               Zinzana        1         Jordan
# 10515                Zodiac        0  United States
# 10516            Zombieland        0  United States
# 10517                  Zoom        0  United States
# 10518                Zubaan        0          India
#
# [10519 rows x 3 columns]

# %%
df_country=df_country[["title",0]]
df_country
# Out:
#                       title              0
# 0      Dick Johnson Is Dead  United States
# 1             Blood & Water   South Africa
# 2                 Ganglands            nan
# 3              Kota Factory          India
# 4             Midnight Mass            nan
# ...                     ...            ...
# 10514               Zinzana         Jordan
# 10515                Zodiac  United States
# 10516            Zombieland  United States
# 10517                  Zoom  United States
# 10518                Zubaan          India
#
# [10519 rows x 2 columns]

# %%
df_country.columns=["title","country"]
df_country
# Out:
#                       title        country
# 0      Dick Johnson Is Dead  United States
# 1             Blood & Water   South Africa
# 2                 Ganglands            nan
# 3              Kota Factory          India
# 4             Midnight Mass            nan
# ...                     ...            ...
# 10514               Zinzana         Jordan
# 10515                Zodiac  United States
# 10516            Zombieland  United States
# 10517                  Zoom  United States
# 10518                Zubaan          India
#
# [10519 rows x 2 columns]

# %%
df_country.replace("nan",np.nan,inplace=True)
df_country.isna().sum()
# Out:
# /tmp/ipykernel_783/4252768545.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_country.replace("nan",np.nan,inplace=True)
# title        0
# country    730
# dtype: int64

# %%
df12=df_cast.merge(df_genre,on="title")
df12
# Out:
#                        title                   cast                   genre
# 0       Dick Johnson Is Dead                    NaN           Documentaries
# 1              Blood & Water             Ama Qamata  International TV Shows
# 2              Blood & Water             Ama Qamata               TV Dramas
# 3              Blood & Water             Ama Qamata            TV Mysteries
# 4              Blood & Water            Khosi Ngema  International TV Shows
# ...                      ...                    ...                     ...
# 146662                Zubaan         Anita Shabdish    International Movies
# 146663                Zubaan         Anita Shabdish        Music & Musicals
# 146664                Zubaan  Chittaranjan Tripathy                  Dramas
# 146665                Zubaan  Chittaranjan Tripathy    International Movies
# 146666                Zubaan  Chittaranjan Tripathy        Music & Musicals
#
# [146667 rows x 3 columns]

# %%
df123=df_director.merge(df12,on="title")
df123
# Out:
#                        title         director                   cast  \
# 0       Dick Johnson Is Dead  Kirsten Johnson                    NaN
# 1              Blood & Water              NaN             Ama Qamata
# 2              Blood & Water              NaN             Ama Qamata
# 3              Blood & Water              NaN             Ama Qamata
# 4              Blood & Water              NaN            Khosi Ngema
# ...                      ...              ...                    ...
# 158309                Zubaan      Mozez Singh         Anita Shabdish
# 158310                Zubaan      Mozez Singh         Anita Shabdish
# 158311                Zubaan      Mozez Singh  Chittaranjan Tripathy
# 158312                Zubaan      Mozez Singh  Chittaranjan Tripathy
# 158313                Zubaan      Mozez Singh  Chittaranjan Tripathy
#
#                          genre
# 0                Documentaries
# 1       International TV Shows
# 2                    TV Dramas
# 3                 TV Mysteries
# 4       International TV Shows
# ...                        ...
# 158309    International Movies
# 158310        Music & Musicals
# 158311                  Dramas
# 158312    International Movies
# 158313        Music & Musicals
#
# [158314 rows x 4 columns]

# %%
df1234=df_country.merge(df123,on="title")
df1234
# Out:
#                        title        country         director  \
# 0       Dick Johnson Is Dead  United States  Kirsten Johnson
# 1              Blood & Water   South Africa              NaN
# 2              Blood & Water   South Africa              NaN
# 3              Blood & Water   South Africa              NaN
# 4              Blood & Water   South Africa              NaN
# ...                      ...            ...              ...
# 198399                Zubaan          India      Mozez Singh
# 198400                Zubaan          India      Mozez Singh
# 198401                Zubaan          India      Mozez Singh
# 198402                Zubaan          India      Mozez Singh
# 198403                Zubaan          India      Mozez Singh
#
#                          cast                   genre
# 0                         NaN           Documentaries
# 1                  Ama Qamata  International TV Shows
# 2                  Ama Qamata               TV Dramas
# 3                  Ama Qamata            TV Mysteries
# 4                 Khosi Ngema  International TV Shows
# ...                       ...                     ...
# 198399         Anita Shabdish    International Movies
# 198400         Anita Shabdish        Music & Musicals
# 198401  Chittaranjan Tripathy                  Dramas
# 198402  Chittaranjan Tripathy    International Movies
# 198403  Chittaranjan Tripathy        Music & Musicals
#
# [198404 rows x 5 columns]

# %%
df_new=df.merge(df1234,on="title")
df_new
# Out:
#            type                 title       director_x  \
# 0         Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1       TV Show         Blood & Water              NaN
# 2       TV Show         Blood & Water              NaN
# 3       TV Show         Blood & Water              NaN
# 4       TV Show         Blood & Water              NaN
# ...         ...                   ...              ...
# 198399    Movie                Zubaan      Mozez Singh
# 198400    Movie                Zubaan      Mozez Singh
# 198401    Movie                Zubaan      Mozez Singh
# 198402    Movie                Zubaan      Mozez Singh
# 198403    Movie                Zubaan      Mozez Singh
#
#                                                    cast_x      country_x  \
# 0                                                     NaN  United States
# 1       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 3       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 4       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...                                                   ...            ...
# 198399  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# 198400  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# 198401  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# 198402  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# 198403  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#        date_added  release_year  rating  duration  \
# 0      2021-09-25          2020   Teens        90
# 1      2021-09-24          2021  Adults         2
# 2      2021-09-24          2021  Adults         2
# 3      2021-09-24          2021  Adults         2
# 4      2021-09-24          2021  Adults         2
# ...           ...           ...     ...       ...
# 198399 2019-03-02          2015   Teens       111
# 198400 2019-03-02          2015   Teens       111
# 198401 2019-03-02          2015   Teens       111
# 198402 2019-03-02          2015   Teens       111
# 198403 2019-03-02          2015   Teens       111
#
#                                                 genre_x  \
# 0                                         Documentaries
# 1       International TV Shows, TV Dramas, TV Mysteries
# 2       International TV Shows, TV Dramas, TV Mysteries
# 3       International TV Shows, TV Dramas, TV Mysteries
# 4       International TV Shows, TV Dramas, TV Mysteries
# ...                                                 ...
# 198399   Dramas, International Movies, Music & Musicals
# 198400   Dramas, International Movies, Music & Musicals
# 198401   Dramas, International Movies, Music & Musicals
# 198402   Dramas, International Movies, Music & Musicals
# 198403   Dramas, International Movies, Music & Musicals
#
#                                               description  day  month  year  \
# 0       As her father nears the end of his life, filmm...   25      9  2021
# 1       After crossing paths at a party, a Cape Town t...   24      9  2021
# 2       After crossing paths at a party, a Cape Town t...   24      9  2021
# 3       After crossing paths at a party, a Cape Town t...   24      9  2021
# 4       After crossing paths at a party, a Cape Town t...   24      9  2021
# ...                                                   ...  ...    ...   ...
# 198399  A scrappy but poor boy worms his way into a ty...    2      3  2019
# 198400  A scrappy but poor boy worms his way into a ty...    2      3  2019
# 198401  A scrappy but poor boy worms his way into a ty...    2      3  2019
# 198402  A scrappy but poor boy worms his way into a ty...    2      3  2019
# 198403  A scrappy but poor boy worms his way into a ty...    2      3  2019
#
#        month_name   weekday      country_y       director_y  \
# 0       September  Saturday  United States  Kirsten Johnson
# 1       September    Friday   South Africa              NaN
# 2       September    Friday   South Africa              NaN
# 3       September    Friday   South Africa              NaN
# 4       September    Friday   South Africa              NaN
# ...           ...       ...            ...              ...
# 198399      March  Saturday          India      Mozez Singh
# 198400      March  Saturday          India      Mozez Singh
# 198401      March  Saturday          India      Mozez Singh
# 198402      March  Saturday          India      Mozez Singh
# 198403      March  Saturday          India      Mozez Singh
#
#                        cast_y                 genre_y
# 0                         NaN           Documentaries
# 1                  Ama Qamata  International TV Shows
# 2                  Ama Qamata               TV Dramas
# 3                  Ama Qamata            TV Mysteries
# 4                 Khosi Ngema  International TV Shows
# ...                       ...                     ...
# 198399         Anita Shabdish    International Movies
# 198400         Anita Shabdish        Music & Musicals
# 198401  Chittaranjan Tripathy                  Dramas
# 198402  Chittaranjan Tripathy    International Movies
# 198403  Chittaranjan Tripathy        Music & Musicals
#
# [198404 rows x 20 columns]

# %%
df_new.drop(columns=["cast_x","country_x","director_x","genre_x"],inplace=True)
df_new
# Out:
#            type                 title date_added  release_year  rating  \
# 0         Movie  Dick Johnson Is Dead 2021-09-25          2020   Teens
# 1       TV Show         Blood & Water 2021-09-24          2021  Adults
# 2       TV Show         Blood & Water 2021-09-24          2021  Adults
# 3       TV Show         Blood & Water 2021-09-24          2021  Adults
# 4       TV Show         Blood & Water 2021-09-24          2021  Adults
# ...         ...                   ...        ...           ...     ...
# 198399    Movie                Zubaan 2019-03-02          2015   Teens
# 198400    Movie                Zubaan 2019-03-02          2015   Teens
# 198401    Movie                Zubaan 2019-03-02          2015   Teens
# 198402    Movie                Zubaan 2019-03-02          2015   Teens
# 198403    Movie                Zubaan 2019-03-02          2015   Teens
#
#         duration                                        description  day  \
# 0             90  As her father nears the end of his life, filmm...   25
# 1              2  After crossing paths at a party, a Cape Town t...   24
# 2              2  After crossing paths at a party, a Cape Town t...   24
# 3              2  After crossing paths at a party, a Cape Town t...   24
# 4              2  After crossing paths at a party, a Cape Town t...   24
# ...          ...                                                ...  ...
# 198399       111  A scrappy but poor boy worms his way into a ty...    2
# 198400       111  A scrappy but poor boy worms his way into a ty...    2
# 198401       111  A scrappy but poor boy worms his way into a ty...    2
# 198402       111  A scrappy but poor boy worms his way into a ty...    2
# 198403       111  A scrappy but poor boy worms his way into a ty...    2
#
#         month  year month_name   weekday      country_y       director_y  \
# 0           9  2021  September  Saturday  United States  Kirsten Johnson
# 1           9  2021  September    Friday   South Africa              NaN
# 2           9  2021  September    Friday   South Africa              NaN
# 3           9  2021  September    Friday   South Africa              NaN
# 4           9  2021  September    Friday   South Africa              NaN
# ...       ...   ...        ...       ...            ...              ...
# 198399      3  2019      March  Saturday          India      Mozez Singh
# 198400      3  2019      March  Saturday          India      Mozez Singh
# 198401      3  2019      March  Saturday          India      Mozez Singh
# 198402      3  2019      March  Saturday          India      Mozez Singh
# 198403      3  2019      March  Saturday          India      Mozez Singh
#
#                        cast_y                 genre_y
# 0                         NaN           Documentaries
# 1                  Ama Qamata  International TV Shows
# 2                  Ama Qamata               TV Dramas
# 3                  Ama Qamata            TV Mysteries
# 4                 Khosi Ngema  International TV Shows
# ...                       ...                     ...
# 198399         Anita Shabdish    International Movies
# 198400         Anita Shabdish        Music & Musicals
# 198401  Chittaranjan Tripathy                  Dramas
# 198402  Chittaranjan Tripathy    International Movies
# 198403  Chittaranjan Tripathy        Music & Musicals
#
# [198404 rows x 16 columns]

# %%
df_new.rename(columns={"country_y":"country","director_y":"director","cast_y":"cast","genre_y":"genre"},inplace=True)

# %%
df_new.shape
# Out:
# (198404, 16)

# %%
df_new.isnull().sum()
# Out:
# type                0
# title               0
# date_added          0
# release_year        0
# rating              0
# duration            0
# description         0
# day                 0
# month               0
# year                0
# month_name          0
# weekday             0
# country         11699
# director        48645
# cast             1882
# genre               0
# dtype: int64

# %%
#here we will not delete the missing values as it will affect the data and other columns
df_new["cast"]=df_new["cast"].replace(np.nan,"Unknown")
df_new["country"]=df_new["country"].replace(np.nan,"Unknown")
df_new["director"]=df_new["director"].replace(np.nan,"unknown")

# %%
df_new.head()
# Out:
#       type                 title date_added  release_year  rating  duration  \
# 0    Movie  Dick Johnson Is Dead 2021-09-25          2020   Teens        90
# 1  TV Show         Blood & Water 2021-09-24          2021  Adults         2
# 2  TV Show         Blood & Water 2021-09-24          2021  Adults         2
# 3  TV Show         Blood & Water 2021-09-24          2021  Adults         2
# 4  TV Show         Blood & Water 2021-09-24          2021  Adults         2
#
#                                          description  day  month  year  \
# 0  As her father nears the end of his life, filmm...   25      9  2021
# 1  After crossing paths at a party, a Cape Town t...   24      9  2021
# 2  After crossing paths at a party, a Cape Town t...   24      9  2021
# 3  After crossing paths at a party, a Cape Town t...   24      9  2021
# 4  After crossing paths at a party, a Cape Town t...   24      9  2021
#
#   month_name   weekday        country         director         cast  \
# 0  September  Saturday  United States  Kirsten Johnson      Unknown
# 1  September    Friday   South Africa          unknown   Ama Qamata
# 2  September    Friday   South Africa          unknown   Ama Qamata
# 3  September    Friday   South Africa          unknown   Ama Qamata
# 4  September    Friday   South Africa          unknown  Khosi Ngema
#
#                     genre
# 0           Documentaries
# 1  International TV Shows
# 2               TV Dramas
# 3            TV Mysteries
# 4  International TV Shows

# %%
df_new.drop(["description"],axis=1,inplace=True)

# %%
df_new.duplicated().sum()
# Out:
# np.int64(55)

# %%
#in the new dataframe, we can see 55 rows which are duplicated, so deleting them
df_new.drop_duplicates(keep="first",inplace=True)

# %%
#creating 2 more dataframe for better analysis by deviding the present dataframe on the basis of type column
df_movies=df_new[df_new["type"]=="Movie"]
df_tvs=df_new[df_new["type"]=="TV Show"]

# %%
df_movies.shape
# Out:
# (144240, 15)

# %%
df_tvs.shape
# Out:
# (54109, 15)

# %%
df_tvs.rename(columns={"duration":"seasons"},inplace=True)
# Out:
# /tmp/ipykernel_783/2462203523.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tvs.rename(columns={"duration":"seasons"},inplace=True)

# %%
#import matplotlib.pyplot as plt
plt.pie(df["type"].value_counts(),labels=df["type"].value_counts().index,
        autopct="%1.2f%%",explode=[0.03,0.04],shadow=True)
plt.suptitle("Movies vs TV Shows distribution")
plt.show()

# %%
df_temp=df_new.drop_duplicates(subset=["country","title"])
df_temp
# Out:
#            type                 title date_added  release_year  rating  \
# 0         Movie  Dick Johnson Is Dead 2021-09-25          2020   Teens
# 1       TV Show         Blood & Water 2021-09-24          2021  Adults
# 58      TV Show             Ganglands 2021-09-24          2021  Adults
# 85      TV Show          Kota Factory 2021-09-24          2021  Adults
# 109     TV Show         Midnight Mass 2021-09-24          2021  Adults
# ...         ...                   ...        ...           ...     ...
# 198300    Movie               Zinzana 2016-03-09          2015  Adults
# 198318    Movie                Zodiac 2019-11-20          2007  Adults
# 198348    Movie            Zombieland 2019-11-01          2009  Adults
# 198362    Movie                  Zoom 2020-01-11          2006    Kids
# 198380    Movie                Zubaan 2019-03-02          2015   Teens
#
#         duration  day  month  year month_name    weekday        country  \
# 0             90   25      9  2021  September   Saturday  United States
# 1              2   24      9  2021  September     Friday   South Africa
# 58             1   24      9  2021  September     Friday        Unknown
# 85             2   24      9  2021  September     Friday          India
# 109            1   24      9  2021  September     Friday        Unknown
# ...          ...  ...    ...   ...        ...        ...            ...
# 198300        96    9      3  2016      March  Wednesday         Jordan
# 198318       158   20     11  2019   November  Wednesday  United States
# 198348        88    1     11  2019   November     Friday  United States
# 198362        88   11      1  2020    January   Saturday  United States
# 198380       111    2      3  2019      March   Saturday          India
#
#                director             cast                     genre
# 0       Kirsten Johnson          Unknown             Documentaries
# 1               unknown       Ama Qamata    International TV Shows
# 58      Julien Leclercq    Sami Bouajila            Crime TV Shows
# 85              unknown       Mayur More    International TV Shows
# 109       Mike Flanagan      Kate Siegel                 TV Dramas
# ...                 ...              ...                       ...
# 198300  Majid Al Ansari      Ali Suliman                    Dramas
# 198318    David Fincher     Mark Ruffalo               Cult Movies
# 198348  Ruben Fleischer  Jesse Eisenberg                  Comedies
# 198362     Peter Hewitt        Tim Allen  Children & Family Movies
# 198380      Mozez Singh    Vicky Kaushal                    Dramas
#
# [10519 rows x 15 columns]

# %%
x=df_temp["country"].value_counts().head(10)
x
# Out:
# country
# United States     3596
# India             1038
# United Kingdom     772
# Unknown            730
# Canada             427
# France             383
# Japan              313
# Spain              228
# Germany            223
# South Korea        222
# Name: count, dtype: int64

# %%
plt.figure(figsize=(17,8))
plt.title("Content across Countries")
label=sns.countplot(data=df_temp,x="country",hue="type",order=x.index)
for i in label.containers:
  label.bar_label(i)
  plt.show()

# %%
df_movies_temp=df_movies.drop_duplicates(subset=["director","title"])
df_tvs_temp=df_tvs.drop_duplicates(subset=["director","title"])

# %%
df_movies_temp = df_movies.drop_duplicates(subset = ['director','title'])
df_tvs_temp = df_tvs.drop_duplicates(subset = ['director','title'])

plt.figure(figsize = (17,7))
plt.suptitle('Top 10 Directors')

plt.subplot(1,2,1)
x=df_movies_temp['director'].value_counts()[1:11]
label = sns.countplot(data=df_movies_temp, x='director', order = x.index,palette="husl")
for i in label.containers:
    label.bar_label(i)
plt.title("Movies")
plt.xticks(rotation=45)
plt.xlabel('Directors')
plt.ylabel('Movie Count')

plt.subplot(1,2,2)
y=df_tvs_temp['director'].value_counts()[1:11]
label = sns.countplot(data=df_tvs_temp, x='director', order = y.index,palette="husl")
for i in label.containers:
    label.bar_label(i)
plt.title("TV Shows")
plt.xticks(rotation=45)
plt.xlabel('Directors')
plt.ylabel('TV Show Count')
plt.show()
# Out:
# /tmp/ipykernel_783/2509367928.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   label = sns.countplot(data=df_movies_temp, x='director', order = x.index,palette="husl")
# /tmp/ipykernel_783/2509367928.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   label = sns.countplot(data=df_tvs_temp, x='director', order = y.index,palette="husl")

# %%
df_movies_temp = df_movies.drop_duplicates(subset = ['genre','title'])
df_tvs_temp = df_tvs.drop_duplicates(subset = ['genre','title'])

plt.figure(figsize = (17,7))
plt.suptitle('Top 10 genre')

plt.subplot(1,2,1)
x=df_movies_temp['genre'].value_counts()[1:11]
label = sns.countplot(data=df_movies_temp, x='genre', order = x.index,palette="husl")
for i in label.containers:
    label.bar_label(i)
plt.title("Movies")
plt.xticks(rotation=45)
plt.xlabel('genre')
plt.ylabel('Movie Count')

plt.subplot(1,2,2)
y=df_tvs_temp['genre'].value_counts()[1:11]
label = sns.countplot(data=df_tvs_temp, x='genre', order = y.index,palette="husl")
for i in label.containers:
    label.bar_label(i)
plt.title("TV Shows")
plt.xticks(rotation=45)
plt.xlabel('genre')
plt.ylabel('TV Show Count')
plt.show()
# Out:
# /tmp/ipykernel_783/2739010199.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   label = sns.countplot(data=df_movies_temp, x='genre', order = x.index,palette="husl")
# /tmp/ipykernel_783/2739010199.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   label = sns.countplot(data=df_tvs_temp, x='genre', order = y.index,palette="husl")

# %%
df_movies_temp = df_movies.drop_duplicates(subset = ['rating','title'])
df_tvs_temp = df_tvs.drop_duplicates(subset = ['rating','title'])

plt.figure(figsize = (12,6))
plt.suptitle('Classification of Content on Netflix')

plt.subplot(1,2,1)
plt.pie(df_movies_temp['rating'].value_counts(),labels=df_movies_temp['rating'].value_counts().index,autopct='%0.0f%%',explode=(0.05,0.03,0.03),shadow=True)
plt.title("Movies")

plt.subplot(1,2,2)
plt.pie(df_tvs_temp['rating'].value_counts(),labels=df_tvs_temp['rating'].value_counts().index,autopct='%0.0f%%',explode=(0.05,0.03,0.03),shadow=True)
plt.title('TV Shows')
plt.show()

# %%
df_tvs.rename(columns={"duration":"season"},inplace=True)
# Out:
# /tmp/ipykernel_783/2173718200.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tvs.rename(columns={"duration":"season"},inplace=True)

# %%
df_movies_temp = df_movies.drop_duplicates(subset = ['duration','title'])
df_tvs_temp = df_tvs.drop_duplicates(subset = ['seasons','title'])

plt.figure(figsize = (17,8))
plt.suptitle('Average Duration and Seasons of Content on Netflix')

plt.subplot(1,2,1)
label=sns.histplot(df_movies_temp['duration'],bins=10,kde=True)
for i in label.containers:
    label.bar_label(i)
plt.xlabel("Duration")
plt.title('Movies')

plt.subplot(1,2,2)
label=sns.histplot(df_tvs_temp['seasons'],bins=10,kde=True)
for i in label.containers:
    label.bar_label(i)
plt.xlabel('Season')
plt.title('TV Shows')
plt.show()

# %%
df_movies_temp=df_movies.drop_duplicates(subset=["year","title"])
df_movies_temp
# Out:
#          type                             title date_added  release_year  \
# 0       Movie              Dick Johnson Is Dead 2021-09-25          2020
# 157     Movie  My Little Pony: A New Generation 2021-09-24          2021
# 177     Movie                           Sankofa 2021-09-24          1993
# 329     Movie                      The Starling 2021-09-24          2021
# 426     Movie                      Je Suis Karl 2021-09-23          2021
# ...       ...                               ...        ...           ...
# 198282  Movie                           Zinzana 2016-03-09          2015
# 198318  Movie                            Zodiac 2019-11-20          2007
# 198348  Movie                        Zombieland 2019-11-01          2009
# 198362  Movie                              Zoom 2020-01-11          2006
# 198380  Movie                            Zubaan 2019-03-02          2015
#
#         rating  duration  day  month  year month_name    weekday  \
# 0        Teens        90   25      9  2021  September   Saturday
# 157       Kids        91   24      9  2021  September     Friday
# 177     Adults       125   24      9  2021  September     Friday
# 329      Teens       104   24      9  2021  September     Friday
# 426     Adults       127   23      9  2021  September   Thursday
# ...        ...       ...  ...    ...   ...        ...        ...
# 198282  Adults        96    9      3  2016      March  Wednesday
# 198318  Adults       158   20     11  2019   November  Wednesday
# 198348  Adults        88    1     11  2019   November     Friday
# 198362    Kids        88   11      1  2020    January   Saturday
# 198380   Teens       111    2      3  2019      March   Saturday
#
#                      country             director              cast  \
# 0              United States      Kirsten Johnson           Unknown
# 157                  Unknown        Robert Cullen   Vanessa Hudgens
# 177            United States         Haile Gerima      Kofi Ghanaba
# 329            United States       Theodore Melfi  Melissa McCarthy
# 426                  Germany  Christian Schwochow       Luna Wedler
# ...                      ...                  ...               ...
# 198282  United Arab Emirates      Majid Al Ansari       Ali Suliman
# 198318         United States        David Fincher      Mark Ruffalo
# 198348         United States      Ruben Fleischer   Jesse Eisenberg
# 198362         United States         Peter Hewitt         Tim Allen
# 198380                 India          Mozez Singh     Vicky Kaushal
#
#                            genre
# 0                  Documentaries
# 157     Children & Family Movies
# 177                       Dramas
# 329                     Comedies
# 426                       Dramas
# ...                          ...
# 198282                    Dramas
# 198318               Cult Movies
# 198348                  Comedies
# 198362  Children & Family Movies
# 198380                    Dramas
#
# [6031 rows x 15 columns]

# %%
mv_year=df_movies_temp["year"].value_counts()
mv_year.sort_index(inplace=True)
mv_year
# Out:
# year
# 2008       1
# 2009       2
# 2011      13
# 2012       3
# 2013       3
# 2014      19
# 2015      51
# 2016     224
# 2017     813
# 2018    1223
# 2019    1412
# 2020    1281
# 2021     986
# Name: count, dtype: int64

# %%
month_order=["January","February","March","April","May","June","July","August","September","October","November","December"]
mv_month=df_movies_temp["month_name"].value_counts().loc[month_order]
mv_month
# Out:
# month_name
# January      535
# February     375
# March        518
# April        542
# May          433
# June         485
# July         559
# August       515
# September    510
# October      535
# November     489
# December     535
# Name: count, dtype: int64

# %%
day_order=["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"]
mv_day=df_movies_temp["weekday"].value_counts().loc[day_order]
mv_day
# Out:
# weekday
# Monday        612
# Tuesday       842
# Wednesday     895
# Thursday     1040
# Friday       1537
# Saturday      543
# Sunday        562
# Name: count, dtype: int64

# %%
plt.figure(figsize=(17,8))
plt.suptitle("Movies added on Netflix")
plt.subplot(1,3,1)
label=sns.countplot(data=df_movies_temp,x="year",order=mv_year.index,palette="viridis")
for i in label.containers:
    label.bar_label(i)
plt.xticks(rotation=45)
plt.xlabel("Year")
plt.title("Year wise")

plt.subplot(1,3,2)
label=sns.countplot(data=df_movies_temp,x="month_name",order=mv_month.index,palette="husl")
for i in label.containers:
    label.bar_label(i)
plt.xticks(rotation=45)
plt.xlabel("Month")
plt.title("Month wise")

plt.subplot(1,3,3)
label=sns.countplot(data=df_movies_temp,x="weekday",order=mv_day.index,palette="husl")
for i in label.containers:
    label.bar_label(i)
plt.xticks(rotation=45)
plt.xlabel("Weekday")
plt.title("Day wise")
plt.show()
# Out:
# /tmp/ipykernel_783/1543357884.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   label=sns.countplot(data=df_movies_temp,x="year",order=mv_year.index,palette="viridis")
# /tmp/ipykernel_783/1543357884.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   label=sns.countplot(data=df_movies_temp,x="month_name",order=mv_month.index,palette="husl")
# /tmp/ipykernel_783/1543357884.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   label=sns.countplot(data=df_movies_temp,x="weekday",order=mv_day.index,palette="husl")

# %%
df_tvs_temp = df_tvs.drop_duplicates(subset = ['year','title'])

tv_year = df_tvs_temp['year'].value_counts()
tv_year.sort_index(inplace=True)

month_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July','August', 'September', 'October', 'November', 'December']
tv_month = df_tvs_temp['month_name'].value_counts().loc[month_order]

day_order = ['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday']
tv_day = df_tvs_temp['weekday'].value_counts().loc[day_order]


plt.figure(figsize=(17,8))
plt.suptitle('TV Shows added on Netflix')

plt.subplot(1,3,1)
label = sns.countplot(data=df_tvs_temp, x='year', order = tv_year.index)
for i in label.containers:
    label.bar_label(i)
plt.xticks(rotation=45)
plt.xlabel('Year')
plt.title('Year wise')

plt.subplot(1,3,2)
label = sns.countplot(data=df_tvs_temp, x='month_name', order = tv_month.index)
for i in label.containers:
    label.bar_label(i)
plt.xticks(rotation=45)
plt.xlabel('Month')
plt.title('Month wise')

plt.subplot(1,3,3)
label = sns.countplot(data=df_tvs_temp, x='weekday', order = tv_day.index)
for i in label.containers:
    label.bar_label(i)
plt.xticks(rotation=45)
plt.xlabel('Weekday')
plt.title('Day wise')
plt.show()

# %%
plt.figure(figsize=(17,8))
plt.suptitle("Average Duration and Seasons of Content on Netflix")
plt.subplot(1,2,1)
sns.boxplot(y=df_movies_temp["duration"])
plt.title("Movies")
plt.subplot(1,2,2)
sns.boxplot(y=df_tvs_temp["seasons"])
plt.title("TV Shows")
plt.show()

# %%
df_movies_temp = df_movies.drop_duplicates(subset = ['cast','title'])
df_tvs_temp = df_tvs.drop_duplicates(subset = ['cast','title'])

plt.figure(figsize = (17,7))
plt.suptitle('Top 10 cast')

plt.subplot(1,2,1)
x=df_movies_temp['cast'].value_counts()[1:11]
label = sns.countplot(data=df_movies_temp, x='cast', order = x.index,palette="husl")
for i in label.containers:
    label.bar_label(i)
plt.title("Movies")
plt.xticks(rotation=45)
plt.xlabel('cast')
plt.ylabel('Movie Count')

plt.subplot(1,2,2)
y=df_tvs_temp['cast'].value_counts()[1:11]
label = sns.countplot(data=df_tvs_temp, x='cast', order = y.index,palette="husl")
for i in label.containers:
    label.bar_label(i)
plt.title("TV Shows")
plt.xticks(rotation=45)
plt.xlabel('cast')
plt.ylabel('TV Show Count')
plt.show()
# Out:
# /tmp/ipykernel_783/343679172.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   label = sns.countplot(data=df_movies_temp, x='cast', order = x.index,palette="husl")
# /tmp/ipykernel_783/343679172.py:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   label = sns.countplot(data=df_tvs_temp, x='cast', order = y.index,palette="husl")
